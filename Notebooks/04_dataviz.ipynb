# %% [markdown]
# # DataViz

# %% [markdown]
# Importez la bibliothèque matplotlib et représentez un graphique simple avec plt.plot (plt.show() aussi)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Représentez plusierus nuages de points sur le même graphique et modifiez les axes

# %%
plt.plot(np.random.random(100),np.random.random(100),".",c="red",label="nuage 1")
plt.plot(np.random.random(100),np.random.random(100),".",c="blue",label="nuage 2")
plt.title("Mon graphique")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend(loc=0)

# %% [markdown]
# A partir d’un jeu de données, représentez un nuage de points basé sur deux variables continues

# %%
frame_housing=pd.read_csv("../Data/housing.csv")

# %%
frame_housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
plt.scatter("median_income","median_house_value",c="housing_median_age",data=frame_housing,s=1)
plt.xlabel("median_income")
plt.ylabel("median_house_value")
plt.colorbar()

# %% [markdown]
# Générez un histogramme à partir des données

# %%
plt.hist(frame_housing["median_income"],bins=50,alpha=0.5,label="income")
plt.hist(frame_housing["median_income"]*2,bins=50,alpha=0.5,color="red",label="income2")
plt.legend()

# %% [markdown]
# Représentez les variables sous forme de Box-plot

# %%
import seaborn as sns

# %%
sns.boxplot(frame_housing["ocean_proximity"],frame_housing["median_income"])

# %%
sns.distplot(frame_housing["median_income"])

# %%
sns.pairplot(frame_housing,hue="ocean_proximity")
plt.savefig("pairplot.png")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:748: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= mn)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:749: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= mx)

# %% [markdown]
# ## La Californie en graphique

# %%
californie=plt.imread("../Data/california.png")
plt.scatter("longitude","latitude",data=frame_housing,c="median_house_value",
            s=frame_housing["population"]/100,
           cmap=plt.get_cmap("rainbow"),alpha=0.5)
plt.colorbar().ax.set_ylabel('median house value')

plt.legend(["Population"])
plt.imshow(californie,extent=[-124.55, -113.80, 32.45, 42.05])
